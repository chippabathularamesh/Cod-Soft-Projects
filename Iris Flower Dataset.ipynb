# %%
from PIL import Image

# %%
Image = Image.open(r"C:\Users\rames\Desktop\Iris.jpg")

# %%
Image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=728x410>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\rames\Downloads\IRIS (5).csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Table info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## shape

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Null values

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ## Data Visulization

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.histplot(data = df, x = 'sepal_length',hue= 'species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %% [markdown]
# * The histogram shows that Iris-setosa generally has a smaller sepal length compared to the other species, while Iris-virginica
# * tends to have a larger sepal length. Iris-versicolor is in between, overlapping with the other two species.

# %%
sns.histplot(data = df, x = 'sepal_width')
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %% [markdown]
# * The histogram shows that the sepal width of the Iris dataset is approximately normally distributed, with most values
# * clustered around 3.0 cm. There are fewer instances of sepal widths below 2.5 cm and above 4.0 cm.

# %%
sns.kdeplot(data = df, x = 'sepal_width')
# Out:
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %% [markdown]
# * The density plot indicates that the sepal width in the Iris dataset is unimodal, with the highest density around 3.0 cm.
# * The distribution is slightly skewed to the right, with fewer instances of sepal widths above 3.5 cm.

# %%
sns.kdeplot(data = df, x = 'petal_length')
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %% [markdown]
# * The density plot of petal lengths reveals a bimodal distribution, suggesting the presence of two distinct groups or clusters
# * within the data. This could indicate different species or subspecies of flowers with varying petal lengths.

# %%
sns.kdeplot(data = df, x = 'petal_width')
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %% [markdown]
# * The density plot of petal widths reveals a bimodal distribution, suggesting the presence of two distinct groups or clusters
# * within the data. This could indicate different species or subspecies of flowers with varying petal widths.

# %% [markdown]
# ## categerical Distribution

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.countplot(data = df, x = 'species')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %% [markdown]
# * The bar plot shows the distribution of the three Iris species. The counts of each species are relatively balanced,
# * with approximately 50 instances of each. This suggests that the dataset is well-balanced and does not suffer from class
# * imbalance, which could be a challenge for machine learning models.

# %% [markdown]
# ## identify outliers each varaible

# %%
df.plot(kind="box",subplots=True, figsize=(8,6),layout=(2,2))
plt.show()

# %% [markdown]
# * The box plots reveal that sepal lengths and widths have a wider range of values compared to petal lengths and widths.
# * Additionally, petal lengths and widths exhibit a more skewed distribution, with a longer tail on the right side,
# * indicating the presence of some larger values.

# %%
plt.pie(df['species'].value_counts(),labels = df['species'].unique(),autopct = '%1.1f%%')
plt.show()

# %% [markdown]
# * The pie chart illustrates the distribution of the three Iris species. Each species accounts for 33.3% of the total,
# * indicating a balanced representation in the dataset. This suggests that the dataset is well-balanced and does not
# * suffer from class imbalance, which could be a challenge for machine learning models.

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# * The correlation matrix reveals strong positive correlations between petal length and petal width, suggesting that flowers
# * with longer petals tend to have wider petals. Additionally, there is a moderate negative correlation between sepal
# * length and sepal width, indicating that flowers with longer sepals tend to have narrower sepals.

# %%
sns.pairplot(df.corr(numeric_only=True))
# Out:
# C:\Users\rames\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# * The pair plot reveals that petal length and petal width are positively correlated, suggesting that flowers with longer
# * petals tend to have wider petals. Additionally, there is a moderate negative correlation between sepal length and
# * sepal width, indicating that flowers with longer sepals tend to have narrower sepals. The histograms on the diagonal
# * show the distribution of each feature, revealing that petal length and petal width have a more skewed distribution,
# * with a longer tail on the right side, indicating the presence of some larger values

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# ## segarate the input and output

# %%
y = df['species']

x = df[['sepal_length','sepal_width','petal_length','petal_width']]

# %%
x.head()
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: species, dtype: object

# %% [markdown]
# ## Split the Data into Train and Test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y, test_size=0.25, random_state=0)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (112, 4) (112,)

# %%
print(y_test.shape, y_test.shape)
# Out:
# (38,) (38,)

# %% [markdown]
# ## Data Preparation

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_transformed = pd.DataFrame(scaler.fit_transform(X_train),columns=scaler.get_feature_names_out(),
                                   index = X_train.index)

# %%
X_test_transformed = pd.DataFrame(scaler.transform(X_test),columns=scaler.get_feature_names_out(),
                                  index = X_test.index)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Logistic Regresssion

# %%
from sklearn.linear_model import LogisticRegression

# %%
reg = LogisticRegression()

# %%
reg.fit(X_train_transformed,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = reg.predict(X_test_transformed)

# %% [markdown]
# ### Evalution

# %%
from sklearn import metrics

# %%
LR = metrics.accuracy_score(y_test,y_pred)
LR
# Out:
# 0.9736842105263158

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
classifier = KNeighborsClassifier()

# %%
classifier.fit(X_train_transformed,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_test_pred = classifier.predict(X_test_transformed)

# %% [markdown]
# ### Evalution

# %%
KNN = metrics.accuracy_score(y_test,y_pred)
KNN
# Out:
# 0.9736842105263158

# %% [markdown]
# ## Decission Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier()

# %%
classifier.fit(X_train_transformed,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_test_pred = classifier.predict(X_test_transformed)

# %% [markdown]
# ### Evalution

# %%
DT = metrics.accuracy_score(y_test,y_pred)
DT
# Out:
# 0.9736842105263158

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier = RandomForestClassifier()

# %%
classifier.fit(X_train_transformed,y_train)
# Out:
# RandomForestClassifier()

# %%
y_test_pred = classifier.predict(X_test_transformed)

# %% [markdown]
# ### Evalution

# %%
RT = metrics.accuracy_score(y_test,y_pred)
RT
# Out:
# 0.9736842105263158

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(X_train_transformed,y_train)
# Out:
# SVC()

# %%
y_test_pred = model.predict(X_test_transformed)

# %% [markdown]
# ### Evalution

# %%
SVM = metrics.accuracy_score(y_test,y_pred)
SVM
# Out:
# 0.9736842105263158

# %%
Algorithems = ['Linear Regression','KNN','Decision Trees','Random Forest','SVM']
Accuracy = [LR,KNN,DT,RT,SVM]
plt.figure(figsize=(10,5))
ax = sns.barplot(x = Algorithems,y = Accuracy)
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# * The bar plot shows the performance of five machine learning models (Linear Regression, KNN, Decision Trees, Random Forest,
# * and SVM) on a given dataset. All models achieve a very high accuracy of approximately 0.973684, indicating that they are
# * highly effective in predicting the target variable. However, without additional context, it's difficult to determine which
# * model is the best overall choice. Further analysis, such as evaluating other metrics like precision, recall, F1-score,
# * and considering factors like interpretability and computational cost, would be necessary to make a more informed decision.
